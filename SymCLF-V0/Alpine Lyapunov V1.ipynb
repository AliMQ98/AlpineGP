# %%
import numpy as np
import random
import functools
import yaml
import os
from deap import gp
from alpine.gp.gpsymbreg import GPSymbolicRegressor
import warnings
import ray
from sympy import symbols, lambdify, sin, sqrt, pprint, latex, cos, tanh
from IPython.display import display, Math
from ControllerComp import V_x, f, x, G, Q, R, safe_divideSR, compute_v_and_v_dot2

from Fitness import fitness
from PredictScoreFuncs import predict, score
import Functions
from SymFunctions import read_expression, DeapSimplifier
from V_Vdot_Calculations import compute_v_and_v_dot

import matplotlib.pyplot as plt

# %%
# Define the numerical grid (Domain)
x1_vals = np.linspace(-3, 3, 100)
x2_vals = np.linspace(-3, 3, 100)
X1, X2 = np.meshgrid(x1_vals, x2_vals)

# %%
def main():
    yamlfile = "Lyapunov.yaml"
    filename = yamlfile
    with open(filename) as config_file:
        config_file_data = yaml.safe_load(config_file)

    pset = gp.PrimitiveSetTyped(
        "MAIN",
        [
            float, float
        ],
        float,
    )
    
    pset.renameArguments(ARG0="x1", ARG1="x2")
    
    #pset.addPrimitive(one_minus_cos, (float,), float)

    #def random_constant():
      #  return random.uniform(-10, 10)

    #pset.addEphemeralConstant("rand", functools.partial(random_constant), float)

    #pset.addEphemeralConstant("rand", lambda: random.uniform(-10, 10), float)
    #pset.addTerminal(1, float) 
    
    penalty = config_file_data["gp"]["penalty"]
    common_data = {"penalty": penalty}

    gpsr = GPSymbolicRegressor(
        pset=pset,
        fitness=fitness.remote,
        error_metric=score.remote,
        predict_func=predict.remote,
        common_data=common_data,
        config_file_data=config_file_data,
        print_log=True,
        batch_size=100,
    )

    train_data = Functions.Dataset("true_data", [x1_vals, x2_vals], None)
    gpsr.fit(train_data)

    # Access and save the best individual
    best_expression = gpsr.best  # Save the best expression
    best_fitness = gpsr.train_fit_history[-1]  # Save the best fitness score

    # Write best expression to a file
    with open("best_expression.txt", "w") as file:
        file.write(f"Best Expression:\n{best_expression}\n")
        file.write(f"Best Fitness:\n{best_fitness}\n")

    print("Best Expression and Fitness saved to 'best_expression.txt'.")

    ray.shutdown()


if __name__ == "__main__":
    main()
# Out:
# 2025-02-12 11:22:09,023	INFO worker.py:1832 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# Generating initial population(s)...
# DONE.
#  -= START OF EVOLUTION =-
# Evaluating initial population(s)...
# DONE.
#    	     	            fitness            	             size
#    	     	-------------------------------	------------------------------
# gen	evals	min   	avg    	max    	std    	min	avg   	max	std
# 1  	2000 	1263.5	13179.8	70534.9	7110.19	3  	16.107	93 	12.713
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(x2, x2))))), add(x2, x2))
# 2  	2000 	1263.5	8880.95	10247.9	1659.95	3  	13.757	75 	9.8204
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(x2, x2))))), add(x2, x2))
# 3  	2000 	1263.5	7788.44	10001.1	1709.44	3  	16.07 	77 	11.2919
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(x2, x2))))), add(x2, x2))
# 4  	2000 	1263.5	6670.15	9715.67	1338.85	3  	15.784	77 	11.0128
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(x2, x2))))), add(x2, x2))
# 5  	2000 	1263.5	5862.09	7682.36	1091.9 	3  	16.113	91 	11.909
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(x2, x2))))), add(x2, x2))
# 6  	2000 	1263.5	5241.09	6898.23	1006.96	3  	17.997	83 	13.1683
# Best individuals of this generation:
# add(mul(add(x2, x1), add(add(x2, x1), x1)), mul(x1, x1))
# 7  	2000 	1187.4	4759.15	6522.7 	914.865	3  	18.15 	83 	13.286
# Best individuals of this generation:
# add(add(sub(x1, x1), sub(mul(add(sub(x1, x2), add(add(add(sub(x1, add(x1, x1)), add(x2, x1)), x1), add(sub(x2, x2), x2))), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(add(sub(x1, add(x1, x1)), add(x2, x1)), x2))))), add(x2, x2))
# 8  	2000 	966.553	4430.88	6114.93	948.872	3  	17.371	71 	11.6874
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(sub(mul(sub(x1, add(x1, x1)), add(add(x1, add(x1, x1)), x2)), x1), sub(mul(x1, x1), x2)))), add(x2, x2))
# 9  	2000 	900.216	4143.37	5588.81	1005.22	3  	17.493	67 	10.6699
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(add(add(sub(x1, add(x1, x1)), add(x2, x1)), x1), add(sub(x2, x2), x2))), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(add(sub(x1, add(x1, x1)), add(x2, x1)), x2))))), add(x2, x2))
# 10 	2000 	900.216	3871.75	5003.78	1054.54	3  	18.339	67 	10.2871
# Best individuals of this generation:
# add(add(x1, sub(mul(add(sub(x1, x2), add(add(add(sub(x1, add(x1, x1)), add(x2, x1)), x1), add(sub(x2, x2), x2))), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), add(add(sub(x1, add(x1, x1)), add(x2, x1)), x2))))), add(x2, x2))
# 11 	2000 	725.365	3561.73	5001.3 	1066.69	5  	18.054	53 	9.0227
# Best individuals of this generation:
# add(add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1)))))), x1), sub(x2, x2))
# 12 	2000 	725.365	3287.64	5001.3 	1037.44	5  	18.838	63 	9.2774
# Best individuals of this generation:
# add(add(add(x1, sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1)))))), x1), sub(x2, x2))
# 13 	2000 	498.331	3051.59	4891.69	1007.58	5  	19.991	63 	9.4212
# Best individuals of this generation:
# sub(sub(sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1))))), sub(x2, x2)), sub(mul(sub(x1, add(x1, x1)), add(add(x2, x1), x1)), x1))
# 14 	2000 	498.331	2806.26	4514.88	969.786	7  	21.032	63 	9.2615
# Best individuals of this generation:
# sub(sub(sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1))))), sub(x2, x2)), sub(mul(sub(x1, add(x1, x1)), add(add(x2, x1), x1)), x1))
# 15 	2000 	498.331	2552.26	4381   	929.287	7  	22.069	97 	9.6072
# Best individuals of this generation:
# sub(sub(sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1))))), sub(x2, x2)), sub(mul(sub(x1, add(x1, x1)), add(add(x2, x1), x1)), x1))
# 16 	2000 	498.331	2335.16	4284.6 	871.654	7  	22.003	97 	10.3499
# Best individuals of this generation:
# sub(sub(sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1))))), sub(x2, x2)), sub(mul(sub(x1, add(x1, x1)), add(add(x2, x1), x1)), x1))
# 17 	2000 	498.331	2153.78	4005.96	828.684	7  	22.643	97 	11.2131
# Best individuals of this generation:
# sub(sub(sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1))))), sub(x2, x2)), sub(mul(sub(x1, add(x1, x1)), add(add(x2, x1), x1)), x1))
# 18 	2000 	177.819	2004.41	3742.12	807.807	7  	23.151	97 	12.1393
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, add(x1, x1)))), sub(x2, x1)), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), x1)))
# 19 	2000 	152.189	1850.62	3483.63	782.946	7  	24.113	99 	13.1778
# Best individuals of this generation:
# sub(sub(sub(mul(add(sub(x1, x2), add(x2, x2)), add(x1, add(x2, x1))), sub(x1, sub(mul(x1, x1), mul(sub(x1, add(x1, x1)), add(add(x1, x1), x1))))), sub(x2, x2)), sub(mul(sub(x1, add(x1, x1)), add(add(sub(x1, x2), x1), x1)), x1))
# 20 	2000 	126.342	1732.43	2920.34	777.99 	7  	25.937	99 	14.1534
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, x1))), sub(x2, mul(add(add(add(x1, x2), x1), x1), add(x1, sub(add(x1, x1), x2))))), mul(add(add(x2, x1), x1), add(add(x1, x2), x2)))
# 21 	2000 	86.2069	1627.64	2897.27	772.86 	7  	28.433	99 	14.4852
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, add(x1, x1)))), x2), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), x1)))
# 22 	2000 	86.2069	1507.77	2895.27	771.658	7  	30.024	99 	14.582
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, add(x1, x1)))), x2), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), x1)))
# 23 	2000 	80.1796	1384.35	2895.27	778.138	7  	31.075	99 	15.1581
# Best individuals of this generation:
# sub(mul(add(x1, x2), add(x2, x1)), sub(mul(add(x2, add(x1, add(add(x1, x1), add(x1, add(x1, add(x1, add(x1, x1))))))), sub(x2, add(x2, x1))), mul(x1, x1)))
# 24 	2000 	76.8537	1256.28	2895.27	797.27 	7  	32.661	99 	14.8658
# Best individuals of this generation:
# sub(mul(add(x1, x2), add(x2, x1)), sub(mul(add(add(x1, add(x1, add(add(x1, x1), x1))), add(x1, add(add(x1, x1), add(add(x1, sub(add(x1, x2), sub(x1, x1))), x2)))), sub(x2, add(x2, x1))), mul(x1, x1)))
# 25 	2000 	76.8537	1131.62	2895.27	811.074	7  	34.192	99 	15.2106
# Best individuals of this generation:
# sub(mul(add(x1, x2), add(x2, x1)), sub(mul(add(add(x1, add(x1, add(add(x1, x1), x1))), add(x1, add(add(x1, x1), add(add(x1, sub(add(x1, x2), sub(x1, x1))), x2)))), sub(x2, add(x2, x1))), mul(x1, x1)))
# 26 	2000 	76.8537	1018.79	2895.27	836.969	7  	35.179	97 	15.5
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, add(x1, x1)))), x2), mul(add(add(x2, x1), add(x1, x1)), add(sub(add(add(x1, x2), x1), sub(x2, add(x2, x1))), x1)))
# 27 	2000 	76.8537	910.125	2895.27	846.122	7  	36.167	97 	16.1241
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, add(x1, x1)))), x2), mul(add(add(x2, x1), add(x1, x1)), add(sub(add(add(x1, x2), x1), sub(x2, add(x2, x1))), x1)))
# 28 	2000 	76.8537	817    	2895.27	851.279	7  	37.089	97 	16.5065
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, add(x1, x1)))), x2), mul(add(add(x2, x1), add(x1, x1)), add(sub(add(add(x1, x2), x1), sub(x2, add(x2, x1))), x1)))
# 29 	2000 	76.8537	739.015	2895.27	841.783	7  	37.568	99 	16.9023
# Best individuals of this generation:
# add(sub(sub(x2, mul(x2, add(x1, add(x1, x1)))), x2), mul(add(add(x2, add(x1, x1)), add(x1, x1)), add(add(x2, add(x1, x1)), x1)))
# 30 	2000 	76.8537	674.378	2895.27	819.209	7  	37.835	99 	16.7153
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 31 	2000 	76.8537	625.046	2895.27	795.75 	7  	38.811	99 	17.1899
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 32 	2000 	76.8537	576.536	2895.27	752.245	7  	39.254	99 	16.7224
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 33 	2000 	76.8537	540.984	2402.42	719.308	11 	39.73 	99 	16.9231
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 34 	2000 	76.8537	512.49 	2402.42	707.695	11 	41.094	97 	17.1428
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 35 	2000 	76.8537	481.835	2402.42	694.477	11 	41.603	97 	17.1787
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 36 	2000 	76.8537	450.16 	2402.42	679.727	11 	42.142	97 	16.7945
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 37 	2000 	76.8537	417.75 	2305.89	663.588	15 	43.049	95 	16.4975
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 38 	2000 	76.8537	391.075	2305.89	656.372	15 	43.905	95 	16.0723
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 39 	2000 	76.8537	366.965	2305.89	649.528	15 	44.887	95 	15.8448
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 40 	2000 	76.8537	345.554	2273.91	645.32 	15 	45.724	95 	15.6159
# Best individuals of this generation:
# add(sub(sub(add(x2, x1), mul(x2, add(x1, add(x1, x1)))), sub(add(x2, x1), sub(x2, x2))), mul(add(add(x2, x1), add(x1, x1)), add(add(x2, add(x1, x1)), add(x1, sub(add(x2, x1), x2)))))
# 41 	2000 	60.4717	330.122	2273.91	643.649	15 	46.137	95 	15.1757
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 42 	2000 	60.4717	317.562	2248.19	642.975	19 	46.479	95 	15.0102
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 43 	2000 	60.4717	308.176	2240.64	643.414	23 	46.982	95 	14.5967
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 44 	2000 	60.4717	302.083	2234.75	644.368	23 	47.106	95 	14.6602
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 45 	2000 	60.4717	298.287	2234.41	645.132	23 	47.391	95 	14.8463
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 46 	2000 	60.4717	295.945	2233.53	645.65 	23 	47.995	95 	15.0366
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 47 	2000 	60.4717	294.015	2233.47	646.083	23 	48.969	95 	15.1129
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 48 	2000 	60.4717	293.304	2233.47	646.159	23 	49.794	95 	14.922
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 49 	2000 	60.4717	293.024	2233.41	646.04 	25 	50.397	95 	14.9578
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 50 	2000 	60.4717	292.764	2233.41	645.928	25 	50.846	95 	15.1963
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 51 	2000 	60.4717	292.528	2232.41	645.789	25 	50.757	95 	15.2778
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 52 	2000 	60.4717	292.265	2230.03	645.745	25 	50.676	95 	15.3483
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 53 	2000 	60.4717	291.949	2230.03	645.796	25 	50.608	95 	15.6381
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 54 	2000 	60.4717	291.624	2229.84	645.854	25 	50.729	99 	16.061
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 55 	2000 	60.4717	291.374	2229.84	645.886	25 	50.901	99 	16.5251
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 56 	2000 	60.4717	291.061	2229.03	645.953	25 	51.063	99 	16.9825
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 57 	2000 	60.4717	290.652	2229.03	646.072	25 	51.251	95 	17.3368
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 58 	2000 	60.4717	290.626	2228.84	646.059	25 	51.158	95 	17.3187
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 59 	2000 	60.4717	290.585	2228.84	646.064	25 	51.048	95 	17.4566
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 60 	2000 	60.4717	290.522	2228.8 	646.076	25 	51.147	95 	17.7459
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 61 	2000 	60.4717	290.44 	2228.8 	646.084	25 	51.492	95 	18.117
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 62 	2000 	60.4717	290.388	2228.8 	646.082	25 	51.75 	95 	18.4031
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 63 	2000 	60.4717	290.381	2228.8 	646.06 	25 	51.794	95 	18.3887
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 64 	2000 	60.4717	290.375	2228.8 	646.042	25 	51.819	95 	18.3607
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 65 	2000 	60.4717	290.361	2228.8 	646    	25 	51.914	95 	18.3339
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 66 	2000 	60.4717	290.35 	2228.8 	645.968	25 	51.981	95 	18.3484
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 67 	2000 	60.4717	290.337	2228.8 	645.929	25 	52.142	95 	18.3737
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 68 	2000 	60.4717	290.319	2228.8 	645.875	25 	52.385	95 	18.5055
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 69 	2000 	60.4717	290.313	2228.03	645.857	25 	52.679	97 	18.8058
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 70 	2000 	60.4717	290.312	2227.84	645.854	25 	53.213	97 	19.3122
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 71 	2000 	60.4717	290.312	2227.84	645.853	25 	53.788	99 	19.7992
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 72 	2000 	60.4717	290.312	2227.84	645.852	25 	53.78 	99 	19.7925
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 73 	2000 	60.4717	290.311	2227.84	645.851	29 	53.73 	99 	19.8291
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 74 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 75 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 76 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 77 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 78 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 79 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 80 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 81 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 82 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 83 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 84 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 85 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 86 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 87 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 88 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 89 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 90 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 91 	2000 	60.4717	290.311	2227.8 	645.85 	29 	53.682	99 	19.8695
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 92 	2000 	60.4717	290.304	2227.8 	645.83 	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 93 	2000 	60.4717	290.304	2227.8 	645.83 	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 94 	2000 	60.4717	290.304	2227.8 	645.83 	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 95 	2000 	60.4717	290.304	2227.8 	645.83 	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 96 	2000 	60.4717	290.304	2227.8 	645.83 	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 97 	2000 	60.4717	290.304	2227.8 	645.83 	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 98 	2000 	60.4717	290.304	2227.8 	645.83 	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 99 	2000 	60.4717	290.263	2227.8 	645.709	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# 100	2000 	60.4717	290.14 	2227.8 	645.349	29 	53.684	99 	19.8679
# Best individuals of this generation:
# add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
#  -= END OF EVOLUTION =-
# The best individual is add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# The best fitness on the training set is 60.4717
# Best Expression and Fitness saved to 'best_expression.txt'.

# %%
expression = read_expression("best_expression.txt") #+ '+ 73'
#read_expression("best_expression.txt") #+ '+ 73'
#'0.01875 * x2**2 + 0.73575 * (1 - cos(x1))'
#'x1**2 + x2**2'

simplified_expr = DeapSimplifier(expression)
display(Math(latex(simplified_expr)))
# Out:
# Original Expression: add(mul(x1, x1), add(add(add(add(add(add(mul(x1, x2), add(mul(x1, x1), mul(x1, x1))), mul(x1, add(x1, x1))), mul(x1, x2)), add(mul(x1, x2), add(mul(x1, x1), add(mul(x1, x1), add(mul(x1, x1), add(mul(x2, x2), add(add(add(mul(x1, add(x1, x1)), add(mul(x1, x1), mul(x1, add(x1, x1)))), mul(x1, add(x1, x1))), mul(x1, x2)))))))), add(mul(x1, x1), add(mul(x1, x1), mul(x2, x1)))), mul(x2, x2)))
# Simplified Expression: 17*x1**2 + 5*x1*x2 + 2*x2**2
# $\displaystyle 17 x_{1}^{2} + 5 x_{1} x_{2} + 2 x_{2}^{2}$

# %%
# Define symbolic variables
x1, x2 = symbols('x1 x2')
V_func = lambdify((x1, x2), simplified_expr, modules='numpy')
V_vals = V_func(X1, X2)

# %%
print(x1_vals.shape)
# Out:
# (100,)

# %%
_, V_grad_mag, V_dot_vals, lambda_vals, u_vals, u_vals2, u_mag = compute_v_and_v_dot(V_vals, x1_vals, x2_vals)

# %%
V_violations = np.count_nonzero(V_vals < 0)
print(V_violations)

Vdot_violations = np.count_nonzero(V_dot_vals > 0)
print(Vdot_violations)
# Out:
# 0
# 0

# %%
import matplotlib.pyplot as plt

X1 = x1_vals
X2 = x2_vals

# Plot V(x1, x2)
plt.figure(figsize=(10, 6))
contour = plt.contourf(X1, X2, V_vals, levels=50, cmap='viridis')
plt.colorbar(contour)
plt.title(r"$V(x_1, x_2)$ Contour Plot")
plt.xlabel(r"$x_1$")
plt.ylabel(r"$x_2$")
plt.grid()
plt.show()

# Plot the contour of V_x1
plt.figure(figsize=(10, 6))
contour = plt.contourf(X1, X2, V_dot_vals, levels=50, cmap='viridis')
plt.colorbar(contour)
plt.title(r"$d V(x_1, x_2) / dt$ Contour Plot")
plt.xlabel(r"$x_1$")
plt.ylabel(r"$x_2$")
plt.grid()
plt.show()

# Plot the contour of lambda_x
plt.figure(figsize=(10, 6))
contour = plt.contourf(X1, X2, lambda_vals, levels=50, cmap='viridis')
plt.colorbar(contour)
plt.title(r"$\lambda(x)$ Contour Plot")
plt.xlabel(r"$x_1$")
plt.ylabel(r"$x_2$")
plt.grid()
plt.show()

print('mean value of lambda:')
print(np.mean(lambda_vals))

# Plot the contour of u
plt.figure(figsize=(10, 6))
contour = plt.contourf(X1, X2, u_vals, levels=50, cmap='viridis')
plt.colorbar(contour)
plt.title(r"$u(x)$ Contour Plot")
plt.xlabel(r"$x_1$")
plt.ylabel(r"$x_2$")
plt.grid()
plt.show()
#levels=np.linspace(-10, 10, 50)
print(np.mean(u_vals))

# Plot the contour of u2
plt.figure(figsize=(10, 6))
contour = plt.contourf(X1, X2, u_vals2, levels=50, cmap='viridis')
plt.colorbar(contour)
plt.title(r"$u_2(x)$ Contour Plot")
plt.xlabel(r"$x_1$")
plt.ylabel(r"$x_2$")
plt.grid()
plt.show()
# Out:
# mean value of lambda:
# 0.08511323406848234
# -1.8189894035458566e-16

# %%
V = simplified_expr
x1, x2 = symbols('x1 x2')
V_grad = V_x(V, x1, x2)
x_vector = x(x1, x2)
f_vector = f(x1, x2)
G_matrix = G(x1, x2)
Q_matrix = Q(x1, x2)
R_matrix = R(x1, x2)

V_func, V_dot_func, lambda_func, u_func, u_func2, u_mag, b_norm_squared = compute_v_and_v_dot2(V)

print(u_func)
u_func
# Out:
# (-5*x1 - 4*x2)*(x2*(34*x1 + 5*x2) + (5*x1 + 4*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)) + sqrt((5*x1 + 4*x2)**2*(x1**2 + x2**2) + (x2*(34*x1 + 5*x2) + (5*x1 + 4*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)))**2))/(5*x1 + 4*x2)**2
# (-5*x1 - 4*x2)*(x2*(34*x1 + 5*x2) + (5*x1 + 4*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)) + sqrt((5*x1 + 4*x2)**2*(x1**2 + x2**2) + (x2*(34*x1 + 5*x2) + (5*x1 + 4*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)))**2))/(5*x1 + 4*x2)**2

# %%
b_norm_squared
# Out:
# (5*x1 + 4*x2)**2

# %%
print(V_dot_func)
# Out:
# x2*(34*x1 + 5*x2) + (-5*x1 - 4*x2)*(x2*(34*x1 + 5*x2) + (5*x1 + 4*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)) + sqrt((5*x1 + 4*x2)**2*(x1**2 + x2**2) + (x2*(34*x1 + 5*x2) + (5*x1 + 4*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)))**2))/(5*x1 + 4*x2) + (5*x1 + 4*x2)*(-2.66666666666667*x2 - 19.62*sin(x1))

# %%
from sympy import symbols, Function, Matrix, Eq, dsolve
from SystemDynamics import f, G, Q, R
from NumSol import NumSol
import matplotlib.pyplot as plt

# %%
x1, x2 = symbols('x1 x2')

from sympy import symbols, lambdify, diff, Matrix, sin, cos, exp, log, sqrt, tanh

#u_func = -0.025467670686794*x1 - 0.19026288312708*x2
#u_func = 20 * tanh(-23.28 * x1 + -5.27 * x2)
#u_func = (-73*x1 - 40*x2)*(sqrt((73*x1 + 40*x2)**2*(x1**2 + x2**2) + (x2*(126*x1 + 73*x2) + (73*x1 + 40*x2)*(0.666666666666667*x2 - 19.62*sin(x1)))**2) + (x2*(126*x1 + 73*x2) + (73*x1 + 40*x2)*(0.666666666666667*x2 - 19.62*sin(x1)))/(73*x1 + 40*x2)**2)
#u_func = (-68*x1 - 144*x2)*(sqrt((68*x1 + 144*x2)**2*(x1**2 + x2**2) + (x2*(32*x1 + 68*x2) + (68*x1 + 144*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)))**2) + (x2*(32*x1 + 68*x2) + (68*x1 + 144*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)))/(68*x1 + 144*x2)**2)

T = 4
x1_0, x2_0 = 4, 0
#3,0 #-3, -3#-2.5, 0#1, 1# 4, 0
#t_vals, x1_vals, x2_vals = NumSol(u_func, T, x1_0, x2_0)

# %%
u_func_LQR = -0.025467670686794*x1 - 0.19026288312708*x2
t_vals_L, x1_vals_L, x2_vals_L = NumSol(u_func_LQR, T, x1_0, x2_0, None)

u_func_NN = 20 * tanh(-23.28 * x1  -5.27 * x2)
t_vals_N, x1_vals_N, x2_vals_N = NumSol(u_func_NN, T, x1_0, x2_0, None)

#u_func_CLF = (-68*x1 - 144*x2)*(sqrt((68*x1 + 144*x2)**2*(x1**2 + x2**2) + (x2*(32*x1 + 68*x2) + (68*x1 + 144*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)))**2) + (x2*(32*x1 + 68*x2) + (68*x1 + 144*x2)*(-2.66666666666667*x2 - 19.62*sin(x1)))/(68*x1 + 144*x2)**2)
u_func_CLF = u_func2
t_vals_C, x1_vals_C, x2_vals_C = NumSol(u_func_CLF, T, x1_0, x2_0, b_norm_squared)

# %%
# Plot the solution
plt.figure(figsize=(10, 6))

plt.plot(t_vals_L, x1_vals_L, label="x1(t) - LQR", color="red", linestyle='--')
plt.plot(t_vals_L, x2_vals_L, label="x2(t) - LQR", color="orange", linestyle='--')

plt.plot(t_vals_N, x1_vals_N, label="x1(t) - NN", color="red", linestyle=':')
plt.plot(t_vals_N, x2_vals_N, label="x2(t) - NN", color="orange", linestyle=':')

plt.plot(t_vals_C, x1_vals_C, label="x1(t) - CLF", color="red")
plt.plot(t_vals_C, x2_vals_C, label="x2(t) - CLF", color="orange")
'''
plt.plot(time[0:10], x_list[0:10, 0], label="x1(t) - MCP", color="red", linestyle='-.')
plt.plot(time[0:10], x_list[0:10, 1], label="x2(t) - MPC", color="orange", linestyle='-.')
'''
plt.xlabel("Time (t)")
plt.ylabel("State Variables")
plt.legend()
plt.title("Numerical Solution of the Dynamical System")
plt.grid()
plt.show()


# Plot the 2D trajectory (state space path)
plt.figure(figsize=(10, 6))

plt.plot(x1_vals_L, x2_vals_L, label="Path in State Space - LQR", color="purple")
plt.plot(x1_vals_N, x2_vals_N, label="Path in State Space - NN", color="red")
plt.plot( x1_vals_C, x2_vals_C, label="Path in State Space - CLF", color="green")
'''
plt.plot(x_list[:, 0], x_list[:, 1], label="Path in State Space - MPC", color="b")
'''
plt.scatter(x1_0, x2_0, color="green", label="Start", zorder=5)  # Start point
plt.scatter(0, 0, color="red", label="End", zorder=5)  # End point

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("2D Trajectory in State Space (x1 vs x2)")
plt.legend()
plt.grid()
plt.show()

# %%
from CostFunction import calculate_cost

# Calculate the cost
cost_LQR, cost_LQR1, cost_LQR2, u_val_LQR = calculate_cost(t_vals_L, x1_vals_L, x2_vals_L, u_func_LQR, None, 0)
print("Total cost for LQR:", cost_LQR, cost_LQR1, cost_LQR2)

cost_NN, cost_NN1, cost_NN2, u_val_NN = calculate_cost(t_vals_N, x1_vals_N, x2_vals_N, u_func_NN, None, 0)
print("Total cost for NN:", cost_NN, cost_NN1, cost_NN2)

cost_CLF, cost_CLF1, cost_CLF2, u_val_CLF = calculate_cost(t_vals_C, x1_vals_C, x2_vals_C, u_func_CLF, b_norm_squared, 0)
print("Total cost for CLF:", cost_CLF, cost_CLF1, cost_CLF2)
# Out:
# Total cost for LQR: [[161.68028939]] 161.06199635399406 [[0.61829304]]
# Total cost for NN: [[515.23362225]] 28.42888101151886 [[486.80474124]]
# Total cost for CLF: [[277.98438998]] 26.76226662054218 [[251.22212336]]

# %%
plt.figure(figsize=(10, 6))
plt.plot(t_vals_C, u_val_LQR[:, 1], label="u(x) - LQR", color="purple")
plt.plot(t_vals_C, u_val_NN[:, 1], label="u(x) - NN", color="red")
plt.plot(t_vals_C, u_val_CLF[:, 1], label="u(x) - CLF", color="green")
plt.xlabel("time")
plt.ylabel("u(x)")
plt.title("Plot of Controller over time")
plt.legend()
plt.grid()
plt.show()
