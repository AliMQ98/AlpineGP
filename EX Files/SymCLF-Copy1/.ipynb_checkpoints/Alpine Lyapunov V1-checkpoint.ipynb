# %%
import numpy as np

from Fitness import fitness
from PredictScoreFuncs import predict, score
import V_Vdot_Calculations, Functions

# Constants
g, l, b, m = 9.81, 5, 0.1, 2
A, B = -g / l, -b / m

# %%
# Define the numerical grid (Domain)
x1_vals = np.linspace(-3, 3, 200)
x2_vals = np.linspace(-3, 3, 200)
X1, X2 = np.meshgrid(x1_vals, x2_vals)

# %%
import yaml
import os
from deap import gp
from alpine.gp.gpsymbreg import GPSymbolicRegressor
import warnings





# Ground truth
#x = np.array([x / 10.0 for x in range(-10, 10)])
#y = x**4 + x**3 + x**2 + x



def main():
    yamlfile = "Lyapunov.yaml"
    filename = yamlfile
    with open(filename) as config_file:
        config_file_data = yaml.safe_load(config_file)

    pset = gp.PrimitiveSetTyped(
        "MAIN",
        [
            float, float
        ],
        float,
    )
    pset.renameArguments(ARG0="x1", ARG1="x2")

    penalty = config_file_data["gp"]["penalty"]
    common_data = {"penalty": penalty}

    gpsr = GPSymbolicRegressor(
        pset=pset,
        fitness=fitness.remote,
        error_metric=score.remote,
        predict_func=predict.remote,
        common_data=common_data,
        config_file_data=config_file_data,
        print_log=True,
        batch_size=100,
    )

    train_data = Functions.Dataset("true_data", [x1_vals, x2_vals], None)
    gpsr.fit(train_data)

    ray.shutdown()


if __name__ == "__main__":
    main()
# Out:
# 2025-01-24 13:03:30,704	INFO worker.py:1812 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# Generating initial population(s)...
# DONE.
#  -= START OF EVOLUTION =-
# Evaluating initial population(s)...
# DONE.
#    	     	                      fitness                      	              size
#    	     	---------------------------------------------------	-------------------------------
# gen	evals	min  	avg        	max        	std        	min	avg   	max	std
# 1  	1000 	1e+08	8.85161e+09	1.00001e+10	3.17023e+09	2  	15.737	88 	18.7569
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 2  	1000 	1e+08	7.0003e+09 	1e+10      	4.5496e+09 	2  	25.834	89 	26.1653
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 3  	1000 	1e+08	3.1096e+09 	1e+10      	4.55383e+09	2  	48.177	118	27.4958
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 4  	1000 	1e+08	2.782e+08  	1e+10      	1.31622e+09	4  	63.817	119	13.4766
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 5  	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 6  	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 7  	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 8  	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 9  	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 10 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 11 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 12 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 13 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 14 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 15 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 16 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 17 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 18 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 19 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 20 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# 21 	1000 	1e+08	1e+08      	1e+08      	0          	50 	64.676	119	11.3825
# Best individuals of this generation:
# sub(sub(mul(mul(sub(mul(x2, x1), mul(x2, x1)), mul(add(x2, x1), add(x1, x2))), mul(mul(cos(x2), mul(x2, x1)), cos(add(x2, x1)))), mul(cos(mul(add(x1, x1), sub(x1, x2))), sin(cos(mul(x1, x1))))), cos(cos(sin(cos(sub(x2, x2))))))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 53
#      49     ray.shutdown()
#      52 if __name__ == "__main__":
# ---> 53     main()
#
# Cell In[3], line 47, in main()
#      35 gpsr = GPSymbolicRegressor(
#      36     pset=pset,
#      37     fitness=fitness.remote,
#    (...)
#      43     batch_size=100,
#      44 )
#      46 train_data = Functions.Dataset("true_data", [x1_vals, x2_vals], None)
# ---> 47 gpsr.fit(train_data)
#      49 ray.shutdown()
#
# File ~/AlpineGP/src/alpine/gp/gpsymbreg.py:431, in GPSymbolicRegressor.fit(self, train_data, val_data)
#     429 if self.validate and self.error_metric is not None:
#     430     self.__register_val_funcs()
# --> 431 self.__run()
#
# File ~/AlpineGP/src/alpine/gp/gpsymbreg.py:622, in GPSymbolicRegressor.__run(self)
#     619 for gen in range(self.NGEN):
#     620     cgen = gen + 1
# --> 622     num_evals = self.__evolve_islands(cgen)
#     624     # select the best individuals in the current population
#     625     # (including all islands)
#     626     best_inds = tools.selBest(self.__flatten_list(
#     627         self.pop), k=self.num_best_inds_str)
#
# File ~/AlpineGP/src/alpine/gp/gpsymbreg.py:548, in GPSymbolicRegressor.__evolve_islands(self, cgen)
#     545     if self.preprocess_func is not None:
#     546         self.preprocess_func(invalid_inds[i])
# --> 548 fitnesses = self.toolbox.map(self.toolbox.evaluate_train,
#     549                              self.__flatten_list(invalid_inds))
#     550 fitnesses = self.__unflatten_list(fitnesses, [len(i) for i in invalid_inds])
#     552 for i in range(self.num_islands):
#
# File ~/AlpineGP/src/alpine/gp/gpsymbreg.py:415, in GPSymbolicRegressor.__register_map.<locals>.mapper(f, individuals, toolbox_ref)
#     413     individuals_batch = individuals[i:i+self.batch_size]
#     414     fitnesses.append(f(individuals_batch, toolbox_ref))
# --> 415 fitnesses = list(chain(*ray.get(fitnesses)))
#     416 return fitnesses
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/worker.py:2755, in get(object_refs, timeout)
#    2749     raise ValueError(
#    2750         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2751         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2752     )
#    2754 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2755 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2756 for i, value in enumerate(values):
#    2757     if isinstance(value, RayError):
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/worker.py:882, in Worker.get_objects(self, object_refs, timeout, return_exceptions)
#     872         raise TypeError(
#     873             f"Attempting to call `get` on the value {object_ref}, "
#     874             "which is not an ray.ObjectRef."
#     875         )
#     877 timeout_ms = (
#     878     int(timeout * 1000) if timeout is not None and timeout != -1 else -1
#     879 )
#     880 data_metadata_pairs: List[
#     881     Tuple[ray._raylet.Buffer, bytes]
# --> 882 ] = self.core_worker.get_objects(
#     883     object_refs,
#     884     self.current_task_id,
#     885     timeout_ms,
#     886 )
#     888 debugger_breakpoint = b""
#     889 for data, metadata in data_metadata_pairs:
#
# KeyboardInterrupt:
