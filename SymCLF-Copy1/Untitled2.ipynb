# %%
import matplotlib.pyplot as plt
import numpy as np

# Define grid for x1 and x2
x1_vals = np.linspace(-np.pi, np.pi, 100)
x2_vals = np.linspace(-5, 5, 100)
X1, X2 = np.meshgrid(x1_vals, x2_vals)

# Compute V(x) (assumed to be a function V(x1, x2))
V_vals = V(X1, X2)  # Replace with actual function for V(x)

# Compute system dynamics f(x) (dx1/dt and dx2/dt)
f1 = X2  # dx1/dt = x2
f2 = (-g/l) * np.sin(X1) + (-b/(m*l**2)) * X2  # dx2/dt

# Plot contour of V(x)
plt.figure(figsize=(10, 6))
contour = plt.contourf(X1, X2, V_vals, levels=50, cmap='viridis')
plt.colorbar(contour)

# Plot streamlines
plt.streamplot(X1, X2, f1, f2, color='white', density=1.5, linewidth=0.7, arrowsize=1)

# Labels and formatting
plt.title(r"Contour of $V(x)$ and Streamlines")
plt.xlabel(r"$x_1$")
plt.ylabel(r"$x_2$")
plt.grid()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7 X1, X2 = np.meshgrid(x1_vals, x2_vals)
#       9 # Compute V(x) (assumed to be a function V(x1, x2))
# ---> 10 V_vals = V(X1, X2)  # Replace with actual function for V(x)
#      12 # Compute system dynamics f(x) (dx1/dt and dx2/dt)
#      13 f1 = X2  # dx1/dt = x2
#
# NameError: name 'V' is not defined
